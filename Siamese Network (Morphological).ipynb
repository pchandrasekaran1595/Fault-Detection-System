# %% [markdown]
# <a href="https://colab.research.google.com/github/123prashanth123/Fault-Detection-System/blob/main/Siamese%20Network%20(Morphological).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook Setup

# %%
from IPython.display import clear_output
from google.colab import drive
drive.mount("/content/gdrive")

# !pip install -q --upgrade imgaug
# !pip install -q imagecorruptions

clear_output()

# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch import nn, optim
from torchvision import models, transforms, ops
from torch.utils.data import DataLoader as DL
from torch.utils.data import Dataset

import imgaug
from imgaug import augmenters
from sklearn.model_selection import KFold

import os
import re
import cv2
import random as r
from time import time

import warnings
warnings.filterwarnings("ignore")

# %%
TRANSFORM = transforms.Compose([transforms.ToTensor(), transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),])
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SIZE = 224
SEED = 0
EMBED = 2048
FEATURE_VECTOR_LENGTH = 2048 
DATASET_PATH = "/content/gdrive/My Drive/Datasets/FDS"

# %%
def breaker(num=50, char="*"):
    print("\n" + num*char + "\n")

def BGR2RGB(image):
    return cv2.cvtColor(src=image, code=cv2.COLOR_BGR2RGB)

def downscale(image):
    return cv2.resize(src=image, dsize=(SIZE, SIZE), interpolation=cv2.INTER_AREA)

def open(image, k=11):
    n_image = image.copy()
    return cv2.morphologyEx(src=n_image, op=cv2.MORPH_OPEN, kernel=np.ones((k, k)))

def close(image, k=11):
    n_image = image.copy()
    return cv2.morphologyEx(src=n_image, op=cv2.MORPH_CLOSE, kernel=np.ones((k, k)))

def rotate(image, angle=0):
    n_image = image.copy()
    h, w, _ = image.shape
    M = cv2.getRotationMatrix2D(center=(int(w/2), int(h/2)), angle=angle, scale=1)
    return cv2.warpAffine(src=n_image, M=M, dsize=(w, h), borderMode=cv2.BORDER_REFLECT)

def normalize(x):
    for i in range(x.shape[0]):
        x[i] = (x[i] - torch.min(x[i])) / (torch.max(x[i]) - torch.min(x[i]))
    return x

# %% [markdown]
# # Build Pretrained Models

# %%
class FeatureExtractor(nn.Module):
    def __init__(self):
        super(FeatureExtractor, self).__init__()

        self.model = models.vgg16_bn(pretrained=True, progress=True)
        self.model = nn.Sequential(*[*self.model.children()][:-2])
        self.model.add_module("Adaptive Average Pool", nn.AdaptiveAvgPool2d(output_size=(2, 2)))
        self.model.add_module("Flatten", nn.Flatten())
    
    def forward(self, x):
        return self.model(x)

fea_extractor = FeatureExtractor().to(DEVICE)
fea_extractor.eval()

clear_output()

# %% [markdown]
# # Build Loaders

# %%
def build_dataloaders(part_name: str, num_samples: int, batch_size: int):
#####################################################################################################################################################

    class FEDS(Dataset):
        def __init__(self, X=None, transform=None):
            self.transform = transform
            self.X = X

        def __len__(self):
            return self.X.shape[0]

        def __getitem__(self, idx):
            return self.transform(self.X[idx])
    
#####################################################################################################################################################

    class SiameseDS(Dataset):
        def __init__(self, anchor=None, p_vector=None, n_vector=None):
            self.anchor = anchor
            self.p_vector = p_vector
            self.n_vector = n_vector

            if self.p_vector.shape[0] != self.n_vector.shape[0]:
                min_val = min(self.p_vector.shape[0], self.n_vector.shape[0])
                self.anchor = np.array([anchor for _ in range(min_val)])

                self.pX = np.concatenate((self.anchor, np.expand_dims(self.p_vector[:min_val], axis=1)), axis=1)
                self.nX = np.concatenate((self.anchor, np.expand_dims(self.n_vector[:min_val], axis=1)), axis=1)
                self.py = np.ones((self.pX.shape[0], 1))
                self.ny = np.zeros((self.nX.shape[0], 1))

                self.X = np.concatenate((self.pX, self.nX), axis=0)
                self.y = np.concatenate((self.py, self.ny), axis=0)

            else:
                self.anchor = np.array([anchor for _ in range(self.p_vector.shape[0])])

                self.pX = np.concatenate((self.anchor, np.expand_dims(self.p_vector, axis=1)), axis=1)
                self.nX = np.concatenate((self.anchor, np.expand_dims(self.n_vector, axis=1)), axis=1)
                self.py = np.ones((self.pX.shape[0], 1))
                self.ny = np.zeros((self.nX.shape[0], 1))

                self.X = np.concatenate((self.pX, self.nX), axis=0)
                self.y = np.concatenate((self.py, self.ny), axis=0)

        def __len__(self):
            return self.X.shape[0]

        def __getitem__(self, idx):
            return torch.FloatTensor(self.X[idx]), torch.FloatTensor(self.y[idx])
    
#####################################################################################################################################################

    def get_augments(augment_seed=None): 
        imgaug.seed(entropy=augment_seed)
        dataset_augment = augmenters.Sequential([
            augmenters.HorizontalFlip(p=0.25),
            augmenters.VerticalFlip(p=0.25),
            augmenters.SomeOf(5, [
                augmenters.blur.GaussianBlur(sigma=(0, 5), seed=augment_seed),
                augmenters.blur.MedianBlur(k=(1, 7), seed=augment_seed),
                augmenters.size.Crop(percent=(0, 0.15), seed=augment_seed),
                augmenters.geometric.Affine(rotate=(-45, 45), scale=(0.75, 1.25), translate_percent=(-0.15, 0.15), seed=augment_seed, cval=(0, 255), mode="symmetric"),
                augmenters.geometric.Rot90(k=(1, 3), seed=augment_seed),
                augmenters.arithmetic.Dropout(p=(0, 0.075), seed=augment_seed),
                augmenters.arithmetic.SaltAndPepper(p=(0, 0.075), seed=augment_seed),
                augmenters.color.MultiplyBrightness(mul=(0.5, 1.5)),
                augmenters.color.MultiplySaturation(mul=(0, 5), seed=augment_seed),
                augmenters.iaa_convolutional.Sharpen(alpha=(0.75, 1), lightness=(0.75, 1.25), seed=augment_seed),
                augmenters.iaa_convolutional.Emboss(alpha=(0.75, 1), strength=(0.75, 1.25), seed=augment_seed),
                augmenters.contrast.CLAHE(seed=augment_seed),
                augmenters.contrast.GammaContrast(gamma=(0.2, 5), seed=augment_seed),
            ])
        ])
                                                
        return dataset_augment
    
#####################################################################################################################################################

    def make_data(part_name=None, cls="Positive", num_samples=None, batch_size=64, fea_extractor=None):
        path = os.path.join(os.path.join(DATASET_PATH, part_name), "Positive")
        image = BGR2RGB(cv2.imread(os.path.join(path, "Snapshot_1.png"), cv2.IMREAD_COLOR))

        if re.match(r"Positive", cls, re.IGNORECASE):
            anchor = image.copy()
            angles = [0, 90, 180, 270]
            base_images = []
            for angle in angles:
                base_images.append(rotate(downscale(image), angle))

        elif re.match(r"Negative", cls, re.IGNORECASE):
            kernel_sizes = [19, 21, 23, 25]
            base_images = []
            for kernel_size in kernel_sizes:
                base_images.append(downscale(close(image, kernel_size)))
        
        r.seed(SEED)
        num_samples_per_image = int(num_samples/len(base_images))
        mini_features = torch.zeros(num_samples_per_image, FEATURE_VECTOR_LENGTH).to(DEVICE)
        features = torch.zeros(1, FEATURE_VECTOR_LENGTH).to(DEVICE)
        for image in base_images:

            # plt.figure()
            # plt.imshow(image)
            # plt.show()

            augment_seed = r.randint(0, 99)
            dataset_augment = get_augments(augment_seed)
            images = np.array(dataset_augment(images=[image for _ in range(num_samples_per_image)]))
            feature_data_setup = FEDS(X=images, transform=TRANSFORM)
            feature_data = DL(feature_data_setup, batch_size=batch_size, shuffle=False)
            for i, X in enumerate(feature_data):
                X = X.to(DEVICE)
                with torch.no_grad():
                    output = fea_extractor(X)
                mini_features[i * batch_size: (i * batch_size) + output.shape[0], :] = output
            features = torch.cat((features, mini_features), dim=0)

        del output, mini_features, fea_extractor
        torch.cuda.empty_cache()

        if re.match(r"Positive", cls, re.IGNORECASE):
            return downscale(anchor), normalize(features[1:]).detach().cpu().numpy()
        else:
            return normalize(features[1:]).detach().cpu().numpy()

#####################################################################################################################################################

    def get_single_image_features(image=None):
        with torch.no_grad():
            features = fea_extractor(TRANSFORM(image).to(DEVICE).unsqueeze(dim=0))
        return normalize(features).detach().cpu().numpy()

#####################################################################################################################################################
 
    anchor, p_features = make_data(part_name=part_name, cls="Positive", num_samples=num_samples, batch_size=64, fea_extractor=fea_extractor)
    n_features         = make_data(part_name=part_name, cls="Negative", num_samples=num_samples, batch_size=64, fea_extractor=fea_extractor)

    kf = KFold(n_splits=5, shuffle=True, random_state=SEED).split(n_features)
    for tr_idx, va_idx in kf:
        train_indices, valid_indices = tr_idx, va_idx
        break
    
    anchor = get_single_image_features(image=anchor)
    p_train, p_valid = p_features[train_indices], p_features[valid_indices]
    n_train, n_valid = n_features[train_indices], n_features[valid_indices]

    breaker()
    print("Building Dataloaders ....")
    tr_data_setup = SiameseDS(anchor=anchor, p_vector=p_train, n_vector=n_train)
    va_data_setup = SiameseDS(anchor=anchor, p_vector=p_valid, n_vector=n_valid)

    dataloaders = {
        "train" : DL(tr_data_setup, batch_size=batch_size, shuffle=True, pin_memory=True, generator=torch.manual_seed(SEED), ), 
        "valid" : DL(va_data_setup, batch_size=batch_size, shuffle=False, pin_memory=True)
    }

    return dataloaders

# %% [markdown]
# # Build Model

# %%
def build_siamese_model():
    class SiameseNetwork(nn.Module):
        def __init__(self, IL=FEATURE_VECTOR_LENGTH, embed=EMBED):
            super(SiameseNetwork, self).__init__()

            self.embedder = nn.Sequential()

            self.embedder.add_module("BN", nn.BatchNorm1d(num_features=IL, eps=1e-5))
            self.embedder.add_module("FC", nn.Linear(in_features=IL, out_features=embed))
            self.embedder.add_module("AN", nn.ReLU())

            self.classifier = nn.Sequential()
            self.classifier.add_module("BN", nn.BatchNorm1d(num_features=embed, eps=1e-5))
            self.classifier.add_module("FC", nn.Linear(in_features=embed, out_features=1))
        
        def getOptimizer(self, A_S=True, lr=1e-3, wd=0):
            if A_S:
                return optim.Adam(self.parameters(), lr=lr, weight_decay=wd)
            else:
                return optim.SGD(self.parameters(), lr=lr, weight_decay=wd, momentum=0.9)

        def forward(self, x1, x2=None):
            if x2 is not None:
                x1 = self.embedder(x1)
                x2 = self.embedder(x2)
                x = torch.abs(x1 - x2)
                x = self.classifier(x)
            else:
                x = self.classifier(self.embedder(x1))
            
            return x
        
    torch.manual_seed(SEED)
    model = SiameseNetwork()
    return model

# %% [markdown]
# # Helper

# %%
def train(part_name, model, tr_data, va_data, epochs, lr, wd, es):
    def fit_(model=None, optimizer=None, scheduler=None, epochs=None, early_stopping_patience=None,
             trainloader=None, validloader=None, criterion=None, device=None, path=None, verbose=False):

        def getAccuracy(y_pred=None, y_true=None):
            y_pred, y_true = torch.sigmoid(y_pred).detach(), y_true.detach()

            y_pred[y_pred > 0.5] = 1
            y_pred[y_pred <= 0.5] = 0

            return torch.count_nonzero(y_pred == y_true).item() / len(y_true)
    
        breaker()
        print("Training ...")
        breaker()

        model.to(device)

        DLS = {"train": trainloader, "valid": validloader}
        bestLoss = {"train": np.inf, "valid": np.inf}
        bestAccs = {"train": 0.0, "valid": 0.0}

        Losses = []
        Accuracies = []

        start_time = time()
        for e in range(epochs):
            e_st = time()

            epochLoss = {"train": 0.0, "valid": 0.0}
            epochAccs = {"train": 0.0, "valid": 0.0}

            for phase in ["train", "valid"]:
                if phase == "train":
                    model.train()
                else:
                    model.eval()

                lossPerPass = []
                accsPerPass = []

                for X, y in DLS[phase]:
                    X = X.to(device)
                    if y.dtype == torch.int64:
                        y = y.to(device).view(-1)
                    else:
                        y = y.to(device)

                    optimizer.zero_grad()
                    with torch.set_grad_enabled(phase == "train"):
                        output = model(X[:, 0, :], X[:, 1, :])
                        loss = criterion(output, y)
                        if phase == "train":
                            loss.backward()
                            optimizer.step()
                    lossPerPass.append(loss.item())
                    accsPerPass.append(getAccuracy(output, y))
                epochLoss[phase] = np.mean(np.array(lossPerPass))
                epochAccs[phase] = np.mean(np.array(accsPerPass))
            Losses.append(epochLoss)
            Accuracies.append(epochAccs)

            if early_stopping_patience:
                if epochLoss["valid"] < bestLoss["valid"]:
                    bestLoss = epochLoss
                    BLE = e + 1
                    torch.save({"model_state_dict": model.state_dict(),
                                "optim_state_dict": optimizer.state_dict()},
                            os.path.join(path, "State.pt"))
                    early_stopping_step = 0
                else:
                    early_stopping_step += 1
                    if early_stopping_step > early_stopping_patience:
                        print("\nEarly Stopping at Epoch {}".format(e + 1))
                        break
            
            if epochLoss["valid"] < bestLoss["valid"]:
                bestLoss = epochLoss
                BLE = e + 1
                torch.save({"model_state_dict": model.state_dict(),
                            "optim_state_dict": optimizer.state_dict()},
                            os.path.join(path, "State.pt"))

            if epochAccs["valid"] > bestAccs["valid"]:
                bestAccs = epochAccs
                BAE = e + 1

            if verbose:
                print("Epoch: {} | Train Loss: {:.5f} | Valid Loss: {:.5f} | Train Accs : {:.5f} | \
Valid Accs : {:.5f} | Time: {:.2f} seconds".format(e + 1,
                                                   epochLoss["train"], epochLoss["valid"],
                                                   epochAccs["train"], epochAccs["valid"],
                                                  time() - e_st))

            if scheduler:
                scheduler.step(epochLoss["valid"])

        breaker()
        print("-----> Best Validation Loss at Epoch {}".format(BLE))
        breaker()
        print("-----> Best Validation Accs at Epoch {}".format(BAE))
        breaker()
        print("Time Taken [{} Epochs] : {:.2f} minutes".format(len(Losses), (time() - start_time) / 60))
        breaker()
        print("Training Complete")

        return Losses, Accuracies, BLE, BAE
    
    optimizer = model.getOptimizer(lr=lr, wd=wd)
    checkpoint_path = os.path.join("/content", part_name)
    if not os.path.exists(checkpoint_path):
        os.makedirs(checkpoint_path)

    L, A, BLE, BAE = fit_(model=model, optimizer=optimizer, epochs=epochs, early_stopping_patience=es,
                          trainloader=tr_data, validloader=va_data, criterion=nn.BCEWithLogitsLoss(), 
                          device=DEVICE, path=checkpoint_path, verbose=True)
    
    TL, VL, TA, VA = [], [], [], []

    for i in range(len(L)):
        TL.append(L[i]["train"])
        VL.append(L[i]["valid"])
        TA.append(A[i]["train"])
        VA.append(A[i]["valid"])

    breaker()
    x_Axis = np.arange(1, len(L)+1)
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(x_Axis, TL, "r", label="Training Loss")
    plt.plot(x_Axis, VL, "b", label="validation Loss")
    plt.legend()
    plt.grid()
    plt.subplot(1, 2, 2)
    plt.plot(x_Axis, TA, "r", label="Training Accuracy")
    plt.plot(x_Axis, VA, "b", label="validation Accuracy")
    plt.legend()
    plt.grid()
    plt.show()

    return BLE, checkpoint_path

# %% [markdown]
# # Main

# %%
def main():
    ##########################
    num_samples = 15000
    epochs = 1000
    early_stopping = 50
    batch_size = 512
    lr = 1e-6
    wd = 1e-6
    part_name = "Part 2"
    ##########################

    dataloaders = build_dataloaders(part_name=part_name, num_samples=num_samples, batch_size=batch_size)
    model = build_siamese_model()
    BLE, path = train(part_name, model, dataloaders["train"], dataloaders["valid"], epochs, lr, wd, early_stopping)

    # return path

# %%
main()
# Out:
# **************************************************
#
# Building Dataloaders ....
#
# **************************************************
#
# Training ...
#
# **************************************************
#
# Epoch: 1 | Train Loss: 0.66821 | Valid Loss: 0.70152 | Train Accs : 0.59082 | Valid Accs : 0.57062 | Time: 1.98 seconds
# Epoch: 2 | Train Loss: 0.54540 | Valid Loss: 0.57811 | Train Accs : 0.76869 | Valid Accs : 0.66701 | Time: 2.09 seconds
# Epoch: 3 | Train Loss: 0.46675 | Valid Loss: 0.49976 | Train Accs : 0.83502 | Valid Accs : 0.73386 | Time: 1.98 seconds
# Epoch: 4 | Train Loss: 0.41216 | Valid Loss: 0.43688 | Train Accs : 0.86183 | Valid Accs : 0.78542 | Time: 1.99 seconds
# Epoch: 5 | Train Loss: 0.37354 | Valid Loss: 0.39837 | Train Accs : 0.87756 | Valid Accs : 0.81049 | Time: 2.05 seconds
# Epoch: 6 | Train Loss: 0.34320 | Valid Loss: 0.36265 | Train Accs : 0.88834 | Valid Accs : 0.84152 | Time: 1.99 seconds
# Epoch: 7 | Train Loss: 0.31972 | Valid Loss: 0.34040 | Train Accs : 0.89716 | Valid Accs : 0.85040 | Time: 1.99 seconds
# Epoch: 8 | Train Loss: 0.30023 | Valid Loss: 0.32437 | Train Accs : 0.90389 | Valid Accs : 0.85740 | Time: 1.97 seconds
# Epoch: 9 | Train Loss: 0.28397 | Valid Loss: 0.30129 | Train Accs : 0.90889 | Valid Accs : 0.87685 | Time: 2.05 seconds
# Epoch: 10 | Train Loss: 0.27016 | Valid Loss: 0.28975 | Train Accs : 0.91253 | Valid Accs : 0.88218 | Time: 1.98 seconds
# Epoch: 11 | Train Loss: 0.25841 | Valid Loss: 0.27598 | Train Accs : 0.91716 | Valid Accs : 0.89207 | Time: 1.99 seconds
# Epoch: 12 | Train Loss: 0.24763 | Valid Loss: 0.26408 | Train Accs : 0.91961 | Valid Accs : 0.89698 | Time: 2.03 seconds
# Epoch: 13 | Train Loss: 0.23827 | Valid Loss: 0.25119 | Train Accs : 0.92353 | Valid Accs : 0.90566 | Time: 1.97 seconds
# Epoch: 14 | Train Loss: 0.23037 | Valid Loss: 0.24614 | Train Accs : 0.92556 | Valid Accs : 0.90667 | Time: 1.98 seconds
# Epoch: 15 | Train Loss: 0.22211 | Valid Loss: 0.23707 | Train Accs : 0.92873 | Valid Accs : 0.91195 | Time: 2.00 seconds
# Epoch: 16 | Train Loss: 0.21553 | Valid Loss: 0.22906 | Train Accs : 0.93067 | Valid Accs : 0.91692 | Time: 2.00 seconds
# Epoch: 17 | Train Loss: 0.20900 | Valid Loss: 0.22436 | Train Accs : 0.93265 | Valid Accs : 0.91803 | Time: 2.06 seconds
# Epoch: 18 | Train Loss: 0.20277 | Valid Loss: 0.21485 | Train Accs : 0.93483 | Valid Accs : 0.92246 | Time: 1.94 seconds
# Epoch: 19 | Train Loss: 0.19778 | Valid Loss: 0.21459 | Train Accs : 0.93542 | Valid Accs : 0.92028 | Time: 1.94 seconds
# Epoch: 20 | Train Loss: 0.19290 | Valid Loss: 0.20142 | Train Accs : 0.93735 | Valid Accs : 0.92776 | Time: 2.01 seconds
# Epoch: 21 | Train Loss: 0.18840 | Valid Loss: 0.20005 | Train Accs : 0.93998 | Valid Accs : 0.92665 | Time: 1.94 seconds
# Epoch: 22 | Train Loss: 0.18327 | Valid Loss: 0.19397 | Train Accs : 0.94032 | Valid Accs : 0.93069 | Time: 1.95 seconds
# Epoch: 23 | Train Loss: 0.17867 | Valid Loss: 0.19011 | Train Accs : 0.94174 | Valid Accs : 0.93156 | Time: 1.92 seconds
# Epoch: 24 | Train Loss: 0.17517 | Valid Loss: 0.18619 | Train Accs : 0.94331 | Valid Accs : 0.93361 | Time: 2.00 seconds
# Epoch: 25 | Train Loss: 0.17073 | Valid Loss: 0.18137 | Train Accs : 0.94468 | Valid Accs : 0.93433 | Time: 1.95 seconds
# Epoch: 26 | Train Loss: 0.16722 | Valid Loss: 0.17941 | Train Accs : 0.94592 | Valid Accs : 0.93427 | Time: 1.96 seconds
# Epoch: 27 | Train Loss: 0.16424 | Valid Loss: 0.17577 | Train Accs : 0.94740 | Valid Accs : 0.93596 | Time: 2.03 seconds
# Epoch: 28 | Train Loss: 0.16108 | Valid Loss: 0.17162 | Train Accs : 0.94792 | Valid Accs : 0.93752 | Time: 1.92 seconds
# Epoch: 29 | Train Loss: 0.15782 | Valid Loss: 0.16828 | Train Accs : 0.94893 | Valid Accs : 0.94042 | Time: 1.98 seconds
# Epoch: 30 | Train Loss: 0.15472 | Valid Loss: 0.16292 | Train Accs : 0.95082 | Valid Accs : 0.94327 | Time: 1.94 seconds
# Epoch: 31 | Train Loss: 0.15198 | Valid Loss: 0.16192 | Train Accs : 0.95127 | Valid Accs : 0.94227 | Time: 2.06 seconds
# Epoch: 32 | Train Loss: 0.14967 | Valid Loss: 0.15823 | Train Accs : 0.95193 | Valid Accs : 0.94445 | Time: 2.11 seconds
# Epoch: 33 | Train Loss: 0.14693 | Valid Loss: 0.15482 | Train Accs : 0.95327 | Valid Accs : 0.94656 | Time: 1.98 seconds
# Epoch: 34 | Train Loss: 0.14376 | Valid Loss: 0.15470 | Train Accs : 0.95475 | Valid Accs : 0.94500 | Time: 2.04 seconds
# Epoch: 35 | Train Loss: 0.14157 | Valid Loss: 0.15133 | Train Accs : 0.95574 | Valid Accs : 0.94731 | Time: 1.99 seconds
# Epoch: 36 | Train Loss: 0.13886 | Valid Loss: 0.14870 | Train Accs : 0.95673 | Valid Accs : 0.94741 | Time: 1.96 seconds
# Epoch: 37 | Train Loss: 0.13647 | Valid Loss: 0.14623 | Train Accs : 0.95864 | Valid Accs : 0.94929 | Time: 1.98 seconds
# Epoch: 38 | Train Loss: 0.13440 | Valid Loss: 0.14439 | Train Accs : 0.95947 | Valid Accs : 0.95108 | Time: 2.06 seconds
# Epoch: 39 | Train Loss: 0.13208 | Valid Loss: 0.14198 | Train Accs : 0.95911 | Valid Accs : 0.94955 | Time: 1.99 seconds
# Epoch: 40 | Train Loss: 0.13029 | Valid Loss: 0.13900 | Train Accs : 0.95919 | Valid Accs : 0.95222 | Time: 2.01 seconds
# Epoch: 41 | Train Loss: 0.12811 | Valid Loss: 0.13786 | Train Accs : 0.96116 | Valid Accs : 0.95150 | Time: 1.97 seconds
# Epoch: 42 | Train Loss: 0.12642 | Valid Loss: 0.13591 | Train Accs : 0.96129 | Valid Accs : 0.95320 | Time: 2.04 seconds
# Epoch: 43 | Train Loss: 0.12474 | Valid Loss: 0.13535 | Train Accs : 0.96261 | Valid Accs : 0.95189 | Time: 1.99 seconds
# Epoch: 44 | Train Loss: 0.12338 | Valid Loss: 0.13238 | Train Accs : 0.96179 | Valid Accs : 0.95329 | Time: 1.98 seconds
# Epoch: 45 | Train Loss: 0.12077 | Valid Loss: 0.13263 | Train Accs : 0.96391 | Valid Accs : 0.95489 | Time: 1.96 seconds
# Epoch: 46 | Train Loss: 0.11950 | Valid Loss: 0.12924 | Train Accs : 0.96388 | Valid Accs : 0.95440 | Time: 1.96 seconds
# Epoch: 47 | Train Loss: 0.11730 | Valid Loss: 0.12842 | Train Accs : 0.96462 | Valid Accs : 0.95395 | Time: 1.97 seconds
# Epoch: 48 | Train Loss: 0.11570 | Valid Loss: 0.12771 | Train Accs : 0.96560 | Valid Accs : 0.95586 | Time: 1.95 seconds
# Epoch: 49 | Train Loss: 0.11462 | Valid Loss: 0.12607 | Train Accs : 0.96544 | Valid Accs : 0.95505 | Time: 1.97 seconds
# Epoch: 50 | Train Loss: 0.11265 | Valid Loss: 0.12603 | Train Accs : 0.96649 | Valid Accs : 0.95521 | Time: 2.06 seconds
# Epoch: 51 | Train Loss: 0.11098 | Valid Loss: 0.12624 | Train Accs : 0.96693 | Valid Accs : 0.95456 | Time: 1.89 seconds
# Epoch: 52 | Train Loss: 0.10955 | Valid Loss: 0.12375 | Train Accs : 0.96772 | Valid Accs : 0.95505 | Time: 1.98 seconds
# Epoch: 53 | Train Loss: 0.10808 | Valid Loss: 0.12487 | Train Accs : 0.96839 | Valid Accs : 0.95489 | Time: 1.94 seconds
# Epoch: 54 | Train Loss: 0.10753 | Valid Loss: 0.12034 | Train Accs : 0.96827 | Valid Accs : 0.95570 | Time: 1.96 seconds
# Epoch: 55 | Train Loss: 0.10547 | Valid Loss: 0.12338 | Train Accs : 0.96872 | Valid Accs : 0.95528 | Time: 1.85 seconds
# Epoch: 56 | Train Loss: 0.10465 | Valid Loss: 0.12122 | Train Accs : 0.96901 | Valid Accs : 0.95674 | Time: 1.86 seconds
# Epoch: 57 | Train Loss: 0.10280 | Valid Loss: 0.12137 | Train Accs : 0.97052 | Valid Accs : 0.95544 | Time: 1.94 seconds
# Epoch: 58 | Train Loss: 0.10139 | Valid Loss: 0.11998 | Train Accs : 0.97051 | Valid Accs : 0.95586 | Time: 1.98 seconds
# Epoch: 59 | Train Loss: 0.10022 | Valid Loss: 0.12014 | Train Accs : 0.97117 | Valid Accs : 0.95609 | Time: 1.89 seconds
# Epoch: 60 | Train Loss: 0.09904 | Valid Loss: 0.12121 | Train Accs : 0.97176 | Valid Accs : 0.95593 | Time: 1.90 seconds
# Epoch: 61 | Train Loss: 0.09792 | Valid Loss: 0.12012 | Train Accs : 0.97175 | Valid Accs : 0.95544 | Time: 1.82 seconds
# Epoch: 62 | Train Loss: 0.09684 | Valid Loss: 0.11875 | Train Accs : 0.97132 | Valid Accs : 0.95625 | Time: 1.93 seconds
# Epoch: 63 | Train Loss: 0.09542 | Valid Loss: 0.12216 | Train Accs : 0.97263 | Valid Accs : 0.95300 | Time: 1.88 seconds
# Epoch: 64 | Train Loss: 0.09494 | Valid Loss: 0.12094 | Train Accs : 0.97269 | Valid Accs : 0.95397 | Time: 1.90 seconds
# Epoch: 65 | Train Loss: 0.09365 | Valid Loss: 0.12053 | Train Accs : 0.97295 | Valid Accs : 0.95316 | Time: 1.82 seconds
# Epoch: 66 | Train Loss: 0.09228 | Valid Loss: 0.12106 | Train Accs : 0.97409 | Valid Accs : 0.95300 | Time: 1.82 seconds
# Epoch: 67 | Train Loss: 0.09139 | Valid Loss: 0.12301 | Train Accs : 0.97443 | Valid Accs : 0.95202 | Time: 1.92 seconds
# Epoch: 68 | Train Loss: 0.09037 | Valid Loss: 0.12194 | Train Accs : 0.97427 | Valid Accs : 0.95186 | Time: 1.79 seconds
# Epoch: 69 | Train Loss: 0.09016 | Valid Loss: 0.12440 | Train Accs : 0.97372 | Valid Accs : 0.95007 | Time: 1.82 seconds
# Epoch: 70 | Train Loss: 0.08849 | Valid Loss: 0.11868 | Train Accs : 0.97481 | Valid Accs : 0.95365 | Time: 1.93 seconds
# Epoch: 71 | Train Loss: 0.08783 | Valid Loss: 0.12089 | Train Accs : 0.97583 | Valid Accs : 0.95251 | Time: 1.90 seconds
# Epoch: 72 | Train Loss: 0.08649 | Valid Loss: 0.12018 | Train Accs : 0.97558 | Valid Accs : 0.95283 | Time: 1.85 seconds
# Epoch: 73 | Train Loss: 0.08609 | Valid Loss: 0.12913 | Train Accs : 0.97554 | Valid Accs : 0.94877 | Time: 1.84 seconds
# Epoch: 74 | Train Loss: 0.08468 | Valid Loss: 0.12344 | Train Accs : 0.97607 | Valid Accs : 0.95104 | Time: 1.92 seconds
# Epoch: 75 | Train Loss: 0.08380 | Valid Loss: 0.12735 | Train Accs : 0.97676 | Valid Accs : 0.94860 | Time: 1.84 seconds
# Epoch: 76 | Train Loss: 0.08346 | Valid Loss: 0.12878 | Train Accs : 0.97598 | Valid Accs : 0.94893 | Time: 1.82 seconds
# Epoch: 77 | Train Loss: 0.08213 | Valid Loss: 0.12079 | Train Accs : 0.97716 | Valid Accs : 0.95153 | Time: 1.84 seconds
# Epoch: 78 | Train Loss: 0.08142 | Valid Loss: 0.12218 | Train Accs : 0.97679 | Valid Accs : 0.95039 | Time: 1.93 seconds
# Epoch: 79 | Train Loss: 0.08063 | Valid Loss: 0.13076 | Train Accs : 0.97738 | Valid Accs : 0.94828 | Time: 1.87 seconds
# Epoch: 80 | Train Loss: 0.08012 | Valid Loss: 0.12818 | Train Accs : 0.97771 | Valid Accs : 0.94909 | Time: 1.85 seconds
# Epoch: 81 | Train Loss: 0.07927 | Valid Loss: 0.12334 | Train Accs : 0.97831 | Valid Accs : 0.95072 | Time: 1.93 seconds
# Epoch: 82 | Train Loss: 0.07890 | Valid Loss: 0.12878 | Train Accs : 0.97817 | Valid Accs : 0.94893 | Time: 1.89 seconds
# Epoch: 83 | Train Loss: 0.07740 | Valid Loss: 0.12752 | Train Accs : 0.97807 | Valid Accs : 0.94958 | Time: 1.86 seconds
# Epoch: 84 | Train Loss: 0.07718 | Valid Loss: 0.13001 | Train Accs : 0.97833 | Valid Accs : 0.94811 | Time: 1.87 seconds
# Epoch: 85 | Train Loss: 0.07621 | Valid Loss: 0.12615 | Train Accs : 0.97922 | Valid Accs : 0.95023 | Time: 1.95 seconds
# Epoch: 86 | Train Loss: 0.07536 | Valid Loss: 0.13321 | Train Accs : 0.97909 | Valid Accs : 0.94698 | Time: 2.01 seconds
# Epoch: 87 | Train Loss: 0.07492 | Valid Loss: 0.12589 | Train Accs : 0.97964 | Valid Accs : 0.94974 | Time: 1.88 seconds
# Epoch: 88 | Train Loss: 0.07431 | Valid Loss: 0.13228 | Train Accs : 0.98000 | Valid Accs : 0.94730 | Time: 1.95 seconds
# Epoch: 89 | Train Loss: 0.07349 | Valid Loss: 0.13168 | Train Accs : 0.97979 | Valid Accs : 0.94779 | Time: 1.86 seconds
# Epoch: 90 | Train Loss: 0.07291 | Valid Loss: 0.14030 | Train Accs : 0.97957 | Valid Accs : 0.94486 | Time: 1.84 seconds
# Epoch: 91 | Train Loss: 0.07230 | Valid Loss: 0.13230 | Train Accs : 0.98066 | Valid Accs : 0.94763 | Time: 1.88 seconds
# Epoch: 92 | Train Loss: 0.07136 | Valid Loss: 0.13671 | Train Accs : 0.97982 | Valid Accs : 0.94600 | Time: 1.86 seconds
# Epoch: 93 | Train Loss: 0.07094 | Valid Loss: 0.14870 | Train Accs : 0.98112 | Valid Accs : 0.94242 | Time: 1.96 seconds
# Epoch: 94 | Train Loss: 0.07048 | Valid Loss: 0.14582 | Train Accs : 0.98113 | Valid Accs : 0.94356 | Time: 1.86 seconds
# Epoch: 95 | Train Loss: 0.06939 | Valid Loss: 0.14313 | Train Accs : 0.98066 | Valid Accs : 0.94323 | Time: 1.86 seconds
# Epoch: 96 | Train Loss: 0.06894 | Valid Loss: 0.14686 | Train Accs : 0.98129 | Valid Accs : 0.94291 | Time: 1.92 seconds
# Epoch: 97 | Train Loss: 0.06818 | Valid Loss: 0.13536 | Train Accs : 0.98201 | Valid Accs : 0.94698 | Time: 1.87 seconds
# Epoch: 98 | Train Loss: 0.06732 | Valid Loss: 0.14782 | Train Accs : 0.98196 | Valid Accs : 0.94291 | Time: 1.88 seconds
# Epoch: 99 | Train Loss: 0.06709 | Valid Loss: 0.14629 | Train Accs : 0.98259 | Valid Accs : 0.94291 | Time: 1.85 seconds
# Epoch: 100 | Train Loss: 0.06716 | Valid Loss: 0.14978 | Train Accs : 0.98198 | Valid Accs : 0.94274 | Time: 1.94 seconds
# Epoch: 101 | Train Loss: 0.06654 | Valid Loss: 0.14921 | Train Accs : 0.98213 | Valid Accs : 0.94258 | Time: 1.88 seconds
# Epoch: 102 | Train Loss: 0.06576 | Valid Loss: 0.14757 | Train Accs : 0.98255 | Valid Accs : 0.94388 | Time: 1.86 seconds
# Epoch: 103 | Train Loss: 0.06486 | Valid Loss: 0.16265 | Train Accs : 0.98279 | Valid Accs : 0.93809 | Time: 1.93 seconds
# Epoch: 104 | Train Loss: 0.06455 | Valid Loss: 0.15493 | Train Accs : 0.98335 | Valid Accs : 0.94053 | Time: 1.87 seconds
# Epoch: 105 | Train Loss: 0.06384 | Valid Loss: 0.15643 | Train Accs : 0.98281 | Valid Accs : 0.94037 | Time: 1.88 seconds
# Epoch: 106 | Train Loss: 0.06374 | Valid Loss: 0.14856 | Train Accs : 0.98321 | Valid Accs : 0.94258 | Time: 1.87 seconds
# Epoch: 107 | Train Loss: 0.06280 | Valid Loss: 0.15425 | Train Accs : 0.98300 | Valid Accs : 0.94167 | Time: 1.91 seconds
# Epoch: 108 | Train Loss: 0.06295 | Valid Loss: 0.15479 | Train Accs : 0.98281 | Valid Accs : 0.94102 | Time: 1.85 seconds
# Epoch: 109 | Train Loss: 0.06223 | Valid Loss: 0.15976 | Train Accs : 0.98416 | Valid Accs : 0.93971 | Time: 1.86 seconds
# Epoch: 110 | Train Loss: 0.06115 | Valid Loss: 0.16599 | Train Accs : 0.98378 | Valid Accs : 0.93776 | Time: 1.92 seconds
# Epoch: 111 | Train Loss: 0.06107 | Valid Loss: 0.17159 | Train Accs : 0.98336 | Valid Accs : 0.93499 | Time: 1.86 seconds
# Epoch: 112 | Train Loss: 0.06078 | Valid Loss: 0.15569 | Train Accs : 0.98394 | Valid Accs : 0.94069 | Time: 1.86 seconds
# Epoch: 113 | Train Loss: 0.06113 | Valid Loss: 0.16330 | Train Accs : 0.98284 | Valid Accs : 0.93792 | Time: 1.84 seconds
# Epoch: 114 | Train Loss: 0.05982 | Valid Loss: 0.16645 | Train Accs : 0.98473 | Valid Accs : 0.93744 | Time: 1.89 seconds
# Epoch: 115 | Train Loss: 0.05942 | Valid Loss: 0.16726 | Train Accs : 0.98413 | Valid Accs : 0.93646 | Time: 1.85 seconds
# Epoch: 116 | Train Loss: 0.05876 | Valid Loss: 0.16696 | Train Accs : 0.98450 | Valid Accs : 0.93792 | Time: 1.86 seconds
# Epoch: 117 | Train Loss: 0.05818 | Valid Loss: 0.16940 | Train Accs : 0.98465 | Valid Accs : 0.93695 | Time: 1.88 seconds
# Epoch: 118 | Train Loss: 0.05754 | Valid Loss: 0.17264 | Train Accs : 0.98462 | Valid Accs : 0.93565 | Time: 1.83 seconds
# Epoch: 119 | Train Loss: 0.05668 | Valid Loss: 0.17342 | Train Accs : 0.98537 | Valid Accs : 0.93532 | Time: 1.83 seconds
# Epoch: 120 | Train Loss: 0.05685 | Valid Loss: 0.17471 | Train Accs : 0.98518 | Valid Accs : 0.93483 | Time: 1.90 seconds
#
# Early Stopping at Epoch 121
#
# **************************************************
#
# -----> Best Validation Loss at Epoch 70
#
# **************************************************
#
# -----> Best Validation Accs at Epoch 56
#
# **************************************************
#
# Time Taken [121 Epochs] : 3.89 minutes
#
# **************************************************
#
# Training Complete
#
# **************************************************

# %% [markdown]
# # Testing (with different Images)
